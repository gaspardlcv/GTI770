# %%
import numpy as np
import sklearn as skl
import pandas
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier

# %%
data = pandas.read_csv('galaxy_feature_vectors.csv',header=None) #get the features data from the CSV

# %%
#data = data.drop(0, axis=1) # remove ID column from the data
#Split the dataset into train set and test set with equal subject of any class
X_train, X_test, y_train, y_test = train_test_split(data.loc[:,data.columns != 75],data[75], train_size=0.8, stratify=data[75])

# %%
parameters=[{"max_depth":[None,3,5,10,30,50]}]

#Create a decision tree 
clf_dt = DecisionTreeClassifier(random_state=1)

# %%
def CrossValidation_Result(estimator,X,y,parameters):
    clf_dt_cv = GridSearchCV(estimator, parameters, scoring =["accuracy","f1_weighted"],iid=True, cv=10, refit="f1_weighted", return_train_score=True)
    clf_dt_cv.fit(X,y)
    result = pandas.DataFrame(data=clf_dt_cv.cv_results_)
    return result

# %%
r = CrossValidation_Result(clf_dt,X_train,y_train,parameters)
r.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.998570      0.070654         0.004034        0.001564
# 1       0.215867      0.001281         0.002997        0.000165
# 2       0.339043      0.002383         0.003099        0.000252
# 3       0.609099      0.005287         0.003057        0.000230
# 4       0.946433      0.040533         0.003409        0.000319
#
#   param_max_depth               params  split0_test_accuracy  \
# 0            None  {'max_depth': None}              0.898818
# 1               3     {'max_depth': 3}              0.866322
# 2               5     {'max_depth': 5}              0.892171
# 3              10    {'max_depth': 10}              0.915805
# 4              30    {'max_depth': 30}              0.898818
#
#    split1_test_accuracy  split2_test_accuracy  split3_test_accuracy  ...  \
# 0              0.906135              0.892831              0.907613  ...
# 1              0.851441              0.869919              0.855137  ...
# 2              0.885440              0.892831              0.886179  ...
# 3              0.909830              0.904656              0.912047  ...
# 4              0.906135              0.892831              0.907613  ...
#
#    split2_train_f1_weighted  split3_train_f1_weighted  \
# 0                  1.000000                  1.000000
# 1                  0.861426                  0.863405
# 2                  0.897021                  0.905973
# 3                  0.969034                  0.966564
# 4                  1.000000                  1.000000
#
#    split4_train_f1_weighted  split5_train_f1_weighted  \
# 0                  1.000000                  1.000000
# 1                  0.861428                  0.861655
# 2                  0.897403                  0.899067
# 3                  0.972482                  0.968790
# 4                  1.000000                  1.000000
#
#    split6_train_f1_weighted  split7_train_f1_weighted  \
# 0                  1.000000                  1.000000
# 1                  0.860906                  0.864428
# 2                  0.904419                  0.910086
# 3                  0.967145                  0.968711
# 4                  1.000000                  1.000000
#
#    split8_train_f1_weighted  split9_train_f1_weighted  mean_train_f1_weighted  \
# 0                  1.000000                  1.000000                1.000000
# 1                  0.861061                  0.863540                0.862308
# 2                  0.894580                  0.891692                0.899657
# 3                  0.969197                  0.969117                0.969017
# 4                  1.000000                  0.999918                0.999992
#
#    std_train_f1_weighted
# 0               0.000000
# 1               0.001161
# 2               0.005305
# 3               0.001706
# 4               0.000025
#
# [5 rows x 56 columns]
