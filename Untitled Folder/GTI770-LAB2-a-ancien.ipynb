# %%
import numpy as np
import sklearn as skl
import pandas
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier

# %%
data = pandas.read_csv('galaxy_feature_vectors.csv',header=None) #get the features data from the CSV

# %%
#data = data.drop(0, axis=1) # remove ID column from the data
#Split the dataset into train set and test set with equal subject of any class
X_train, X_test, y_train, y_test = train_test_split(data.loc[:,data.columns != 75],data[75], train_size=0.8, stratify=data[75])
# Out:
# /home/adrien/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
parameters=[{"max_depth":[None,3,5,10,30,50]}]

#Create a decision tree 
clf_dt = DecisionTreeClassifier(random_state=1)

# %%
def CrossValidation_Result(estimator,X,y,parameters):
    clf_dt_cv = GridSearchCV(estimator, parameters, scoring =["accuracy","f1_weighted"],iid=True, refit="f1_weighted", return_train_score=True)
    clf_dt_cv.fit(X,y)
    result = pandas.DataFrame(data=clf_dt_cv.cv_results_)
    return result

# %%
r = CrossValidation_Result(clf_dt,X_train,y_train,parameters)
r.head()
# Out:
# /home/adrien/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.621049      0.025413         0.004451        0.000074
# 1       0.145706      0.001614         0.003812        0.000196
# 2       0.232278      0.001879         0.004367        0.000633
# 3       0.410901      0.003518         0.003922        0.000022
# 4       0.608052      0.031784         0.004242        0.000094
#
#   param_max_depth               params  split0_test_accuracy  \
# 0            None  {'max_depth': None}              0.900665
# 1               3     {'max_depth': 3}              0.863193
# 2               5     {'max_depth': 5}              0.898226
# 3              10    {'max_depth': 10}              0.915521
# 4              30    {'max_depth': 30}              0.900665
#
#    split1_test_accuracy  split2_test_accuracy  mean_test_accuracy  ...  \
# 0              0.900177              0.897959            0.899601  ...
# 1              0.857143              0.855146            0.858495  ...
# 2              0.883984              0.885759            0.889324  ...
# 3              0.907276              0.900843            0.907881  ...
# 4              0.900177              0.897959            0.899601  ...
#
#    split1_test_f1_weighted  split2_test_f1_weighted  mean_test_f1_weighted  \
# 0                 0.900163                 0.897969               0.899604
# 1                 0.857053                 0.854625               0.858263
# 2                 0.884023                 0.885779               0.889351
# 3                 0.907302                 0.900871               0.907896
# 4                 0.900163                 0.897969               0.899604
#
#    std_test_f1_weighted  rank_test_f1_weighted  split0_train_f1_weighted  \
# 0              0.001175                      2                  1.000000
# 1              0.003568                      6                  0.862460
# 2              0.006332                      5                  0.903394
# 3              0.005992                      1                  0.970054
# 4              0.001175                      2                  1.000000
#
#    split1_train_f1_weighted  split2_train_f1_weighted  mean_train_f1_weighted  \
# 0                  1.000000                  1.000000                1.000000
# 1                  0.866266                  0.860975                0.863234
# 2                  0.902896                  0.906106                0.904132
# 3                  0.972170                  0.975606                0.972610
# 4                  1.000000                  1.000000                1.000000
#
#    std_train_f1_weighted
# 0               0.000000
# 1               0.002228
# 2               0.001410
# 3               0.002288
# 4               0.000000
#
# [5 rows x 28 columns]
